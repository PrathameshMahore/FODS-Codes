# %% [markdown]
# ASSIGNMENT 1

# %%
#Reading a csv file from disk
import pandas as pd

df=pd.read_csv("IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Writing to specific disk location
df.to_csv('/content/IRIS.csv', index=False)

# %%
#Read a text file from disk
with open('Python.txt', 'r') as file:
    print(file.read())
# Out:
# Hello Everyone!
# Today we are going to read different types of datasets like:
# 1.Text
# 2.csv
# 3.sql
# 4.json
# 5.link
# Thank you.

# %%
with open('Python.txt', 'r') as file:
    print(file.readline())
# Out:
# Hello Everyone!

# %%
#Reading a text file from web
import requests

url = "https://example.com/file.txt"
response = requests.get(url)
data_txt_web = response.text

# Display the content
print(data_txt_web)
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# ...

# %%
#Write a text file
with open('Python.txt', 'w') as file:
    file.write("This is an addition")
with open('Python.txt', 'r') as file:
    print(file.read())
# Out:
# This is an addition

# %%
with open('Python.txt', 'a') as file:
    file.write("This is an addition")
with open('Python.txt', 'r') as file:
    print(file.read())
# Out:
# This is an additionThis is an addition

# %%
#open a excel file
import pandas as pd
df=pd.read_excel("Questions.xlsx")
df
# Out:
#                      Explain Type 1 and Type 2 errors
# 0                                     Explain p-value
# 1   Can you explain the difference between populat...
# 2                       How to handle missing values?
# 3                   What is IQR and why is it useful?
# 4       Explain the concept of skewness in statistics
# 5          Can you describe what box plot represents?
# 6   What is the difference between variance and st...
# 7                  What is z score why is it usseful?
# 8      Difference between covariance and correlartion
# 9   How does the presence of outliers affect the m...
# 10  how do you interprete the vaue of pearson corr...
# 11  Difference between  range, variance, IQR, stan...
# 12  In what cases standard deviation will be a mil...
# 13            When should we go for z test and t test
# 14               What is overfitting and Underfitting

# %%
#print name of excel sheet
xl=pd.ExcelFile("Questions.xlsx")
print(xl.sheet_names)
# Out:
# ['Stat Questions', 'SQL', 'Project']

# %%
# Reading from disk
import xml.etree.ElementTree as ET

tree = ET.parse('sample1 (1).xml')
root = tree.getroot()

# %%
# Reading XML from URL
import requests
from bs4 import BeautifulSoup

url = 'http://example.com/data.xml'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'xml')

# %%
# Writing XML to disk
tree.write('/content/sample1 (1).xml')
